# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("original.csv")#Loading the data set

# %%
# Some basic operations

# %%
df.dtypes
# Out:
# id                                                  int64
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance\t                        int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# ...

# %%
df.size
# Out:
# 168112

# %%
df.shape
# Out:
# (4424, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              4424 non-null   int64
#  1   Marital status                                  4424 non-null   int64
#  2   Application mode                                4424 non-null   int64
#  3   Application order                               4424 non-null   int64
#  4   Course                                          4424 non-null   int64
#  5   Daytime/evening attendance	                     4424 non-null   int64
#  6   Previous qualification                          4424 non-null   int64
#  7   Previous qualification (grade)                  4424 non-null   float64
#  8   Nacionality                                     4424 non-null   int64
# ...

# %%
df.isnull().sum() # checking the null values
# Out:
# id                                                0
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# ...

# %%
#pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
df.describe() # checking the basic description (min,max,mean,std,25%,50%,75% etc.values)
# Out:
#                 id  Marital status  Application mode  Application order  \
# count  4424.000000     4424.000000       4424.000000        4424.000000
# mean   2212.500000        1.178571         18.669078           1.727848
# std    1277.243125        0.605747         17.484682           1.313793
# min       1.000000        1.000000          1.000000           0.000000
# 25%    1106.750000        1.000000          1.000000           1.000000
# 50%    2212.500000        1.000000         17.000000           1.000000
# 75%    3318.250000        1.000000         39.000000           2.000000
# max    4424.000000        6.000000         57.000000           9.000000
#
#             Course  Daytime/evening attendance\t  Previous qualification  \
# count  4424.000000                   4424.000000             4424.000000
# mean   8856.642631                      0.890823                4.577758
# std    2063.566416                      0.311897               10.216592
# ...

# %%
df.head(25) # analyzing the first 25 rows of dataset
# Out:
#     id  Marital status  Application mode  Application order  Course  \
# 0    1               1                17                  5     171
# 1    2               1                15                  1    9254
# 2    3               1                 1                  5    9070
# 3    4               1                17                  2    9773
# 4    5               2                39                  1    8014
# 5    6               2                39                  1    9991
# 6    7               1                 1                  1    9500
# 7    8               1                18                  4    9254
# 8    9               1                 1                  3    9238
# 9   10               1                 1                  1    9238
# 10  11               1                 1                  1    9670
# 11  12               1                 1                  1    9500
# 12  13               1                 1                  2    9853
# ...

# %%
# their is no null values so no need to handle the null values

# %% [markdown]
# ## Visualization

# %%
# visualizing the "Marital Status" Column

# %%
marital_s = df["Marital status"].value_counts()
marital_s
# Out:
# Marital status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(df,x = 'Marital status',width = 0.3,hue = "Target");
plt.yticks(range(0,2200,300))
plt.xticks(ticks = [0,1,2,3,4,5],labels = ["Single","Married","Widows","Divorced","Sperated","registered partnership"])
plt.xlabel("Marital Status Type")
plt.grid()
plt.title("Visualizing 'Marital Status'");

# %%
# visualing the "Target" Column (to check the students status at college)

# %%
plt.figure(figsize = (12,12))
sns.countplot(df,x = 'Target',width = 0.090);
plt.yticks(range(0,2200,300))
plt.grid()
plt.title("Visualizing 'Target'");

# %%
# Visualizing the column "Unemployment Rate"

# %%
plt.figure(figsize = (12,12))
sns.countplot(df,x = 'Unemployment rate',width = 0.60,hue = "Target");
plt.grid()
plt.title("Visualizing 'Unemployment Rate'");

# %%
# visualizing the columns "Curricular units 1st sem (grade)" and "Curricular units 2nd sem (grade)"

# %%
sns.jointplot(x = "Curricular units 1st sem (grade)",y = "Curricular units 2nd sem (grade)",data = df,hue = "Target");

# %%
# visualizing the column "Course" based on "Target" column

# %%
course_count = df["Course"].value_counts()
course_count
# Out:
# Course
# 9500    766
# 9147    380
# 9238    355
# 9085    337
# 9773    331
# 9670    268
# 9991    268
# 9254    252
# 9070    226
# 171     215
# 8014    215
# 9003    210
# 9853    192
# 9119    170
# 9130    141
# 9556     86
# 33       12
# Name: count, dtype: int64

# %%
course = df.groupby(['Course', 'Target']).size().unstack(fill_value=0)
course_names = {
    1: 'Biofuel Production Technologies', 2: 'Animation and Multimedia Design', 
    3: 'Social Service (Evening Attendance)', 4: 'Agronomy', 
    5: 'Communication Design', 6: 'Veterinary Nursing', 
    7: 'Informatics Engineering', 8: 'Equiniculture', 
    9: 'Management', 10: 'Social Service', 
    11: 'Tourism', 12: 'Nursing', 
    13: 'Oral Hygiene', 14: 'Advertising and Marketing Management', 
    15: 'Journalism and Communication', 16: 'Basic Education', 
    17: 'Management (Evening Attendance)'
}
course = course.rename(index=course_names)

course_total = course.sum(axis=1)

course_sorted = course_total.sort_values(ascending = True)

course.loc[course_sorted.index].plot(kind='barh',stacked =True);
plt.xlabel('Number of Students')
plt.legend()
plt.show()

# %%
#visualizing the column "Age at enrollment" based on "Target" column
# usinh kde(kernel density Estimation) plot

# %%
sns.kdeplot(data=df, x="Age at enrollment",color = "red",hue = "Target");
plt.title("Visualizing 'Age at Enrollment'");

# %%
# visualizing the column "Scholarship holder" based on "Target" column
# using kdeplot

# %%
sns.kdeplot(x = "Scholarship holder",data = df,hue = "Target");

# %%
# visualizing the column "international" based on "Target" column
# using kdeplot

# %%
sns.kdeplot(x = "International",data = df,hue = "Scholarship holder");
