# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("comic_characters.csv")# load the file

# %%
df.dtypes # some basic operations
# Out:
# Id                 int64
# Name              object
# Identity          object
# Alignment         object
# Eyes              object
# Hair              object
# Sex               object
# Alive             object
# Appearances        int64
# First_appeared    object
# Planet            object
# Universe          object
# dtype: object

# %%
df.size
# Out:
# 253728

# %%
df.shape
# Out:
# (21144, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21144 entries, 0 to 21143
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              21144 non-null  int64
#  1   Name            21144 non-null  object
#  2   Identity        21144 non-null  object
#  3   Alignment       21144 non-null  object
#  4   Eyes            21144 non-null  object
#  5   Hair            21144 non-null  object
#  6   Sex             21144 non-null  object
#  7   Alive           21144 non-null  object
#  8   Appearances     21144 non-null  int64
#  9   First_appeared  21144 non-null  object
#  10  Planet          21144 non-null  object
#  11  Universe        21144 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()# checking the null values
# Out:
# Id                0
# Name              0
# Identity          0
# Alignment         0
# Eyes              0
# Hair              0
# Sex               0
# Alive             0
# Appearances       0
# First_appeared    0
# Planet            0
# Universe          0
# dtype: int64

# %%
df.head(25)#analyzing the first 25 rows of dataset
# Out:
#     Id                        Name  Identity Alignment      Eyes   Hair  \
# 0    0                   Dave Finn    Secret      Good      Blue  Black
# 1    1             Katherine Power    Secret      Good      Blue    Red
# 2    2                 John Malone    Secret       Bad      Blue  White
# 3    3         Samuel Bradley, Jr.    Public       Bad     Brown  Brown
# 4    4                   Hope Taya    Public       Bad     Brown  Black
# 5    5                       Trygg    Secret       Bad     Black  Black
# 6    6  Boris Dmitravich Razumihin    Public      Good     Brown  Black
# 7    7                 Perry White    Public      Good      Blue  Brown
# 8    8                     Perkins    Public       Bad     Green  White
# 9    9                        Zuhn    Secret       Bad     White  Blond
# 10  10                     Azaziah    Secret       Bad      Blue  White
# 11  11            Vladimir Morakov    Public      Good     Black  Brown
# ...

# %%
df.duplicated()# checking the duplicate data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21139    False
# 21140    False
# 21141    False
# 21142    False
# 21143    False
# Length: 21144, dtype: bool

# %%
# their is no null values so no need to handle the null values

# %% [markdown]
# ## Visualization

# %%
# visualizing the "Identity" Column based on "Alive"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x = "Identity",width = 0.3,hue = "Alive");

# %%
# visualizing the "Alignment" Column based on "Identity"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x ="Alignment",width = 0.3,hue ="Identity");

# %%
# visualizing the "Alignment" Column based on "Universe"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x = "Alignment",width = 0.3,hue = "Universe");

# %%
# visualizing the "Sex" Column based on "Universe"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x = "Sex",width = 0.3,hue = "Universe");

# %%
# visualizing the "Identity" Column based on "Sex"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x = "Identity",width = 0.3,hue = "Sex");

# %%
# visualizing the "Alignment" Column based on "Universe"

# %%
plt.figure(figsize =(16,9))
sns.countplot(df,x = "Alignment",width = 0.3,hue = "Universe");
